# %%
import pandas as pd

# %%
art_df= pd.read_csv('articles_fin_1.csv')
cus_df= pd.read_csv('customers_fin.csv')
tran_df= pd.read_csv('transactions_fin.csv')

# %%
art_df.head(10)
# Out:
#    article_id  product_code               product_name  product_type_no  \
# 0   108775015        108775                  Strap top              253
# 1   108775044        108775                  Strap top              253
# 2   108775051        108775                  Strap top              253
# 3   110065001        110065                 OP T-shirt              306
# 4   110065002        110065                 OP T-shirt              306
# 5   110065011        110065                 OP T-shirt              306
# 6   111586001        111586  Shape Up 30 den 1p Tights              273
# 7   112679048        112679             SWEATSHIRT  OC              252
# 8   112679052        112679             SWEATSHIRT  OC              252
# 9   114428026        114428          Alice BANDEAU 2-p              306
#
#   product_type_name  product_group_name  color_id color_name index_code  \
# 0          Vest top  Garment Upper body         5      Black          A
# ...

# %%
art_df.head(10)
# Out:
#    article_id  product_code               product_name  product_type_no  \
# 0   108775015        108775                  Strap top              253
# 1   108775044        108775                  Strap top              253
# 2   108775051        108775                  Strap top              253
# 3   110065001        110065                 OP T-shirt              306
# 4   110065002        110065                 OP T-shirt              306
# 5   110065011        110065                 OP T-shirt              306
# 6   111586001        111586  Shape Up 30 den 1p Tights              273
# 7   112679048        112679             SWEATSHIRT  OC              252
# 8   112679052        112679             SWEATSHIRT  OC              252
# 9   114428026        114428          Alice BANDEAU 2-p              306
#
#   product_type_name  product_group_name  color_id color_name index_code  \
# 0          Vest top  Garment Upper body         5      Black          A
# ...

# %%
tran_df.head(10)
# Out:
#    transaction_id        date  \
# 0               1  2019-07-01
# 1               2  2019-07-01
# 2               3  2019-07-01
# 3               4  2019-07-01
# 4               5  2019-07-01
# 5               6  2019-07-01
# 6               7  2019-07-01
# 7               8  2019-07-01
# 8               9  2019-07-01
# 9              10  2019-07-01
#
#                                          customer_id  article_id  price  \
# 0  00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   772448002  19.99
# 1  00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   656067005  24.99
# 2  00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   669910001  19.99
# 3  00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   508987007   9.99
# 4  00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   534164002  19.99
# 5  00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   750921001  12.99
# 6  00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   752281001  29.99
# ...

# %%
t_c_df =pd.merge(left=tran_df, right=cus_df, how="left", on="customer_id")

# %%
import numpy as np
t_c_df['gene']=np.nan

# %%
pd.set_option('display.max_rows', 60000)
t_c_df
# Out:
#          transaction_id        date  \
# 0                     1  2019-07-01
# 1                     2  2019-07-01
# 2                     3  2019-07-01
# 3                     4  2019-07-01
# 4                     5  2019-07-01
# ...                 ...         ...
# 7726924         7726925  2019-12-30
# 7726925         7726926  2019-12-30
# 7726926         7726927  2019-12-30
# 7726927         7726928  2019-12-30
# 7726928         7726929  2019-12-30
#
#                                                customer_id  article_id  price  \
# 0        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   772448002  19.99
# 1        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   656067005  24.99
# 2        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   669910001  19.99
# 3        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   508987007   9.99
# 4        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   534164002  19.99
# ...

# %%
for i in range(0,50000):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'
# Out:
# C:\Users\choi_jh\AppData\Local\Temp\ipykernel_18684\2547947339.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_c_df['gene'][i]='10s'

# %%
for i in range(50000,2000000):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'

# %%
for i in range(0,2000000):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'     
    elif t_c_df['age'][i]>=20 and t_c_df['age'][i]<30:
        t_c_df['gene'][i]='20s'
    elif t_c_df['age'][i]>=30 and t_c_df['age'][i]<40:
        t_c_df['gene'][i]='30s'
    elif t_c_df['age'][i]>=40 and t_c_df['age'][i]<50:
        t_c_df['gene'][i]='40s'
    elif t_c_df['age'][i]>=50 and t_c_df['age'][i]<60:
        t_c_df['gene'][i]='50s'
    elif t_c_df['age'][i]>=60 :
        t_c_df['gene'][i]='60s over'
    else:
        t_c_df['gene'][i]='none'

# %%
for i in range(2000001,4000000):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'     
    elif t_c_df['age'][i]>=20 and t_c_df['age'][i]<30:
        t_c_df['gene'][i]='20s'
    elif t_c_df['age'][i]>=30 and t_c_df['age'][i]<40:
        t_c_df['gene'][i]='30s'
    elif t_c_df['age'][i]>=40 and t_c_df['age'][i]<50:
        t_c_df['gene'][i]='40s'
    elif t_c_df['age'][i]>=50 and t_c_df['age'][i]<60:
        t_c_df['gene'][i]='50s'
    elif t_c_df['age'][i]>=60 :
        t_c_df['gene'][i]='60s over'
    else:
        t_c_df['gene'][i]='none'

# %%
for i in range(4000001,6000000):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'     
    elif t_c_df['age'][i]>=20 and t_c_df['age'][i]<30:
        t_c_df['gene'][i]='20s'
    elif t_c_df['age'][i]>=30 and t_c_df['age'][i]<40:
        t_c_df['gene'][i]='30s'
    elif t_c_df['age'][i]>=40 and t_c_df['age'][i]<50:
        t_c_df['gene'][i]='40s'
    elif t_c_df['age'][i]>=50 and t_c_df['age'][i]<60:
        t_c_df['gene'][i]='50s'
    elif t_c_df['age'][i]>=60 :
        t_c_df['gene'][i]='60s over'
    else:
        t_c_df['gene'][i]='none'

# %%
for i in range(6000000,len(t_c_df)):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'     
    elif t_c_df['age'][i]>=20 and t_c_df['age'][i]<30:
        t_c_df['gene'][i]='20s'
    elif t_c_df['age'][i]>=30 and t_c_df['age'][i]<40:
        t_c_df['gene'][i]='30s'
    elif t_c_df['age'][i]>=40 and t_c_df['age'][i]<50:
        t_c_df['gene'][i]='40s'
    elif t_c_df['age'][i]>=50 and t_c_df['age'][i]<60:
        t_c_df['gene'][i]='50s'
    elif t_c_df['age'][i]>=60 :
        t_c_df['gene'][i]='60s over'
    else:
        t_c_df['gene'][i]='none'

# %%
for i in (2000000,4000000):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'     
    elif t_c_df['age'][i]>=20 and t_c_df['age'][i]<30:
        t_c_df['gene'][i]='20s'
    elif t_c_df['age'][i]>=30 and t_c_df['age'][i]<40:
        t_c_df['gene'][i]='30s'
    elif t_c_df['age'][i]>=40 and t_c_df['age'][i]<50:
        t_c_df['gene'][i]='40s'
    elif t_c_df['age'][i]>=50 and t_c_df['age'][i]<60:
        t_c_df['gene'][i]='50s'
    elif t_c_df['age'][i]>=60 :
        t_c_df['gene'][i]='60s over'
    else:
        t_c_df['gene'][i]='none'

# %%
t_c_df.head(1000)
# Out:
#      transaction_id        date  \
# 0                 1  2019-07-01
# 1                 2  2019-07-01
# 2                 3  2019-07-01
# 3                 4  2019-07-01
# 4                 5  2019-07-01
# 5                 6  2019-07-01
# 6                 7  2019-07-01
# 7                 8  2019-07-01
# 8                 9  2019-07-01
# 9                10  2019-07-01
# 10               11  2019-07-01
# 11               12  2019-07-01
# 12               13  2019-07-01
# 13               14  2019-07-01
# 14               15  2019-07-01
# 15               16  2019-07-01
# 16               17  2019-07-01
# 17               18  2019-07-01
# 18               19  2019-07-01
# 19               20  2019-07-01
# 20               21  2019-07-01
# 21               22  2019-07-01
# 22               23  2019-07-01
# 23               24  2019-07-01
# 24               25  2019-07-01
# 25               26  2019-07-01
# 26               27  2019-07-01
# 27               28  2019-07-01
# ...

# %%
for i in range(0, len(t_c_df)):
    if t_c_df['age'][i]>0 and t_c_df['age'][i]<20:
        t_c_df['gene'][i]='10s'     
    elif t_c_df['age'][i]>=20 and t_c_df['age'][i]<30:
        t_c_df['gene'][i]='20s'
    elif t_c_df['age'][i]>=30 and t_c_df['age'][i]<40:
        t_c_df['gene'][i]='30s'
    elif t_c_df['age'][i]>=40 and t_c_df['age'][i]<50:
        t_c_df['gene'][i]='40s'
    elif t_c_df['age'][i]>=50 and t_c_df['age'][i]<60:
        t_c_df['gene'][i]='50s'
    elif t_c_df['age'][i]>=60:
        t_c_df['gene'][i]='60s_over'
    else:
        t_c_df['gene'][i]='none'

# %%
t_c_df.to_csv('tran_cus_join.csv', index=False)

# %%
t_a_df =pd.merge(left=tran_df, right=art_df, how="left", on="article_id")

# %%
t_a_df.to_csv('tran_art_join.csv', index=False)

# %%
t_c_df.groupby(['gene','sales_channel_id']).count()
# Out:
#                            transaction_id     date  customer_id  article_id  \
# gene     sales_channel_id
# 10s      1                          65836    65836        65836       65836
#          2                          85836    85836        85836       85836
# 20s      1                         987756   987756       987756      987756
#          2                        2245261  2245261      2245261     2245261
# 30s      1                         402032   402032       402032      402032
#          2                        1188972  1188972      1188972     1188972
# 40s      1                         397626   397626       397626      397626
#          2                         755574   755574       755574      755574
# 50s      1                         437991   437991       437991      437991
#          2                         807412   807412       807412      807412
# 60s_over 1                         126565   126565       126565      126565
# ...

# %%
chan_distribution=t_c_df.groupby(['gene','sales_channel_id']).count()

# %%
import matplotlib.pyplot as plt
pivot_result = pd.pivot_table(chan_distribution, values="transaction_id", index=["gene"],\
                             columns="sales_channel_id", aggfunc="sum")
print("\n",pivot_result)
# Out:
#  sales_channel_id       1        2
# gene
# 10s                65836    85836
# 20s               987756  2245261
# 30s               402032  1188972
# 40s               397626   755574
# 50s               437991   807412
# 60s_over          126565   226068

# %% [markdown]
# ### 1='오프라인', 2='온라인'_연령별 유통 채널 이용 비율

# %%
pivot_result.plot(kind="barh",stacked=True, fontsize=10)
# Out:
# <AxesSubplot:ylabel='gene'>

# %%
t_c_df.groupby(['gene']).count()
# Out:
#           transaction_id     date  customer_id  article_id    price  \
# gene
# 10s               151672   151672       151672      151672   151672
# 20s              3233017  3233017      3233017     3233017  3233017
# 30s              1591004  1591004      1591004     1591004  1591004
# 40s              1153200  1153200      1153200     1153200  1153200
# 50s              1245403  1245403      1245403     1245403  1245403
# 60s_over          352633   352633       352633      352633   352633
#
#           sales_channel_id       FN   ACTIVE  club_member_status  \
# gene
# 10s                 151672   151672   151672              151338
# 20s                3233017  3233017  3233017             3228749
# 30s                1591004  1591004  1591004             1582295
# 40s                1153200  1153200  1153200             1152006
# 50s                1245403  1245403  1245403             1244068
# 60s_over            352633   352633   352633              352210
#
# ...

# %% [markdown]
# ### 연령대별 주문 수 비교

# %%
t_c_df.groupby(['gene'])["transaction_id"].count().sort_values().plot(kind="barh",stacked=True, fontsize=10)
#
# Out:
# <AxesSubplot:ylabel='gene'>

# %%
t_a_df
# Out:
#          transaction_id        date  \
# 0                     1  2019-07-01
# 1                     2  2019-07-01
# 2                     3  2019-07-01
# 3                     4  2019-07-01
# 4                     5  2019-07-01
# ...                 ...         ...
# 7726924         7726925  2019-12-30
# 7726925         7726926  2019-12-30
# 7726926         7726927  2019-12-30
# 7726927         7726928  2019-12-30
# 7726928         7726929  2019-12-30
#
#                                                customer_id  article_id  price  \
# 0        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   772448002  19.99
# 1        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   656067005  24.99
# 2        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   669910001  19.99
# 3        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   508987007   9.99
# 4        00058bbdde20e5d34b5f2c60698b2d6ee5736dfca9f370...   534164002  19.99
# ...

# %%
t_a_sum=t_a_df.groupby(['sales_channel_id','product_type_name'])[['product_type_name','price']].sum('price')

t_a_sum
# Out:
#                                                  price
# sales_channel_id product_type_name
# 1                Bag                         346935.51
#                  Ballerinas                   17793.33
#                  Belt                        231700.96
#                  Blazer                     1063187.45
#                  Blouse                     1600640.15
#                  Bodysuit                     86658.77
#                  Boots                       192083.78
#                  Bra                        1224213.47
#                  Bra extender                  1807.05
#                  Cardigan                    345269.86
#                  Coat                        556098.72
#                  Costumes                      7783.45
#                  Dress                      2543466.42
#                  Dungarees                    22263.47
#                  Flat shoes                   17285.17
# ...

# %% [markdown]
# ![nn](image/data_visual.png)
